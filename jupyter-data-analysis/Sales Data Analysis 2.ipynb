# %%
import pandas as pd

# %%
df = pd.read_excel(open("./sales-data/Datsun_dataset.xlsx",'rb'), sheet_name='2021')

# %%
# Out:
#                      Group Maker/Brand      Type Segment    Model  \
# 0  Renault-Nissan Alliance      Datsun      Cars       A  Redi-GO
# 1  Renault-Nissan Alliance      Datsun      Cars       B       Go
# 2  Renault-Nissan Alliance      Datsun  UVs/MPVs     MPV      Go+
#
#    2021-01-01 00:00:00  2021-02-01 00:00:00  2021-03-01 00:00:00  \
# 0                  757                 1037                  975
# 1                   65                  220                  129
# 2                  346                  165                   11
#
#    2021-04-01 00:00:00  2021-05-01 00:00:00  2021-06-01 00:00:00  \
# 0                  333                  145                  365
# 1                  208                   70                  218
# 2                   26                    4                    0
#
#    2021-07-01 00:00:00  2021-08-01 00:00:00  2021-09-01 00:00:00  \
# 0                  419                  182                   40
# ...

# %%
from openpyxl import load_workbook


sales_data_dict = {}
sales_data_df =None
sheets = load_workbook("./sales-data/Datsun_dataset.xlsx", read_only=True).sheetnames

for sheet in sheets:
    sales_data_dict[sheet] = pandas.read_excel(open("./sales-data/Datsun_dataset.xlsx",'rb'), sheet_name=sheet)
    if sales_data_df is None:
        sales_data_df = sales_data_dict[sheet]
    else:
        sales_data_df = pd.merge(sales_data_df, sales_data_dict[sheet], on=["Maker/Brand", "Model"])

# %%
sales_data_df
# Out:
#                    Group_x Maker/Brand    Type_x Segment_x    Model  \
# 0  Renault-Nissan Alliance      Datsun      Cars         A  Redi-GO
# 1  Renault-Nissan Alliance      Datsun      Cars         B       Go
# 2  Renault-Nissan Alliance      Datsun  UVs/MPVs       MPV      Go+
#
#    2021-01-01 00:00:00  2021-02-01 00:00:00  2021-03-01 00:00:00  \
# 0                  757                 1037                  975
# 1                   65                  220                  129
# 2                  346                  165                   11
#
#    2021-04-01 00:00:00  2021-05-01 00:00:00  ...  2017-03-01 00:00:00  \
# 0                  333                  145  ...               1551.0
# 1                  208                   70  ...               1072.0
# 2                   26                    4  ...                624.0
#
#    2017-04-01 00:00:00  2017-05-01 00:00:00  2017-06-01 00:00:00  \
# 0               1981.0               1977.0               2791.0
# ...

# %%
sales_data_df =None
sheets = load_workbook("./sales-data/Honda_dataset.xlsx", read_only=True).sheetnames

for sheet in sheets:
    sales_data_dict[sheet] = pandas.read_excel(open("./sales-data/Honda_dataset.xlsx",'rb'), sheet_name=sheet)
    if sales_data_df is None:
        sales_data_df = sales_data_dict[sheet]
    else:
        sales_data_df = pd.merge(sales_data_df, sales_data_dict[sheet], on=["Maker/Brand", "Model"])

# %%
sales_data_df
# Out:
#   Group_x Maker/Brand    Type_x Segment_x       Model  2022-01-01 00:00:00  \
# 0   Honda       Honda      Cars         A       Amaze                 5295
# 1   Honda       Honda      Cars         B  Fit (Jazz)                  420
# 2   Honda       Honda      Cars         C        City                 5638
# 3   Honda       Honda  UVs/MPVs     SUV-B        WR-V                  510
#
#    2022-02-01 00:00:00  2022-03-01 00:00:00 2022-04-01 00:00:00  \
# 0                 3485                 3406                   -
# 1                  420                  120                   -
# 2                 4468                 5824                   -
# 3                  510                  390                   -
#
#   2022-05-01 00:00:00  ... 2017-03-01 00:00:00 2017-04-01 00:00:00  \
# 0                   -  ...                1667                1031
# 1                   -  ...                3013                 642
# ...

# %%
df2 = pandas.read_excel(open("./sales-data/Datsun_dataset.xlsx",'rb'), sheet_name='2019')

# %%
sales_data_df
# Out:
# Empty DataFrame
# ...

# %%
df2
# Out:
#                      Group Maker/Brand      Type Segment    Model  \
# 0  Renault-Nissan Alliance      Datsun      Cars       A  Redi-GO
# 1  Renault-Nissan Alliance      Datsun      Cars       B       Go
# 2  Renault-Nissan Alliance      Datsun  UVs/MPVs     MPV      Go+
#
#    2019-01-01 00:00:00  2019-02-01 00:00:00  2019-03-01 00:00:00  \
# 0                 1272                 1135                  481
# 1                 1314                 1174                  195
# 2                  536                  729                   98
#
#    2019-04-01 00:00:00  2019-05-01 00:00:00  2019-06-01 00:00:00  \
# 0                 1008                  997                  516
# 1                  324                  913                  574
# 2                  795                  169                  417
#
#    2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00  \
# 0                 3086                  923                 1963
# ...

# %%
df1["MakeModel"] = df1["Maker/Brand"] + "_"+ df1["Model"]

# %%
df1.set_index('MakeModel', inplace=True)

# %% [markdown]
# # Data
